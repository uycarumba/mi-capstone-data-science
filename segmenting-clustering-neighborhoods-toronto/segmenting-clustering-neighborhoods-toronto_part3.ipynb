# %% [markdown]
# # Data Science Capstone (Toronto Neighborhoods)

# %% [markdown]
# ## Part 3
# ### Retrieve data from Foursquare
# In this part, we are going to use data available in Foursquare to identify venues near each neighborhood

# %% [markdown]
# ### First, lets plot neighborhoods in a map

# %%
lat, long = df_2['Latitude'][0], df_2['Longitude'][0]

map_toronto = folium.Map(location=[lat, long], zoom_start=10)

for lat, long, label in zip(df_2['Latitude'], df_2['Longitude'], df_2['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Next, lets use Foursquare API and retrieve information about our first neighborhood

# %%
CLIENT_ID = '1XCUXXCEPR21OVC1PCPBR1OPI03GBMZZ4UQJ4Q4LFDQBHLDV'
CLIENT_SECRET = 'H4KQLAQLER5XYNLCE4FE3QMRTXNAYG5ZYCL5I3DAUXCRVR4E'
VERSION = '20180605'

# %%
neighborhood, lat, long = df_2.loc[0, 'Neighborhood'], df_2.loc[0, 'Latitude'], df_2.loc[0, 'Longitude']
print(neighborhood, lat, long)
# Out:
# Parkwoods 43.7532586 -79.3296565

# %%
radius=650
LIMIT=100
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, radius, LIMIT)
results = requests.get(url).json()
# print(results)

# %%
# venues = results['response']['groups'][0]['items']
# venues

# %%
def get_category_name(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
nearby_venues = pd.json_normalize(venues)
# print(nearby_venues.columns)

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng', 'venue.location.distance']
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_name, 1)
nearby_venues.loc[:, filtered_columns]
# Out:
#         venue.name   venue.categories  venue.location.lat  venue.location.lng  \
# 0  Brookbanks Park               Park           43.751976          -79.332140
# 1         PetSmart          Pet Store           43.748639          -79.333488
# 2    Variety Store  Food & Drink Shop           43.751974          -79.333114
# 3   Ranchdale Park               Park           43.751388          -79.322138
# 4             Joey       Burger Joint           43.753441          -79.321640
#
#    venue.location.distance
# 0                      245
# 1                      599
# 2                      312
# 3                      639
# 4                      644

# %% [markdown]
# ### Get venues for each neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_2['Neighborhood'],
                                   latitudes=df_2['Latitude'],
                                   longitudes=df_2['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Queen's Park, Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale
# Downsview
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Canada Post Gateway Processing Centre
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Stn A PO Boxes
# Alderwood, Long Branch
# Northwest
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road , Old Mill North
# Church and Wellesley
# Business reply mail Processing Centre
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %% [markdown]
# ### Show the number of venues by neighborhood

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                  Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                           44
# Alderwood, Long Branch                                              27
# Bathurst Manor, Wilson Heights, Downsview North                     30
# Bayview Village                                                     16
# Bedford Park, Lawrence Manor East                                   40
# ...                                                                ...
# Willowdale, Newtonbrook                                             30
# Woburn                                                              10
# Woodbine Heights                                                    32
# York Mills West                                                     22
# York Mills, Silver Hills                                             4
#
#                                                  Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                            44
# Alderwood, Long Branch                                               27
# Bathurst Manor, Wilson Heights, Downsview North                      30
# Bayview Village                                                      16
# Bedford Park, Lawrence Manor East                                    40
# ...                                                                 ...
# Willowdale, Newtonbrook                                              30
# Woburn                                                               10
# Woodbine Heights                                                     32
# York Mills West                                                      22
# York Mills, Silver Hills                                              4
#
#                                                  Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                           44              44
# Alderwood, Long Branch                              27              27
# Bathurst Manor, Wilson Heights, Downsview North     30              30
# Bayview Village                                     16              16
# Bedford Park, Lawrence Manor East                   40              40
# ...                                                ...             ...
# Willowdale, Newtonbrook                             30              30
# Woburn                                              10              10
# Woodbine Heights                                    32              32
# York Mills West                                     22              22
# York Mills, Silver Hills                             4               4
#
#                                                  Venue Longitude  \
# Neighborhood
# Agincourt                                                     44
# Alderwood, Long Branch                                        27
# Bathurst Manor, Wilson Heights, Downsview North               30
# Bayview Village                                               16
# Bedford Park, Lawrence Manor East                             40
# ...                                                          ...
# Willowdale, Newtonbrook                                       30
# Woburn                                                        10
# Woodbine Heights                                              32
# York Mills West                                               22
# York Mills, Silver Hills                                       4
#
#                                                  Venue Category
# Neighborhood
# Agincourt                                                    44
# Alderwood, Long Branch                                       27
# Bathurst Manor, Wilson Heights, Downsview North              30
# Bayview Village                                              16
# Bedford Park, Lawrence Manor East                            40
# ...                                                         ...
# Willowdale, Newtonbrook                                      30
# Woburn                                                       10
# Woodbine Heights                                             32
# York Mills West                                              22
# York Mills, Silver Hills                                      4
#
# [97 rows x 6 columns]

# %% [markdown]
# ### Show how many unique categories

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 331 uniques categories.

# %% [markdown]
# ### Analyzing each neighborhood

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("-------"+hood+"-------")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue', 'freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print("\n")
# Out:
# -------Agincourt-------
#                   venue  freq
# 0    Chinese Restaurant  0.16
# 1         Shopping Mall  0.07
# 2  Caribbean Restaurant  0.05
# 3                Bakery  0.05
# 4           Supermarket  0.02
#
#
# -------Alderwood, Long Branch-------
#             venue  freq
# 0        Pharmacy  0.11
# 1  Discount Store  0.11
# 2     Pizza Place  0.07
# 3            Park  0.07
# 4             Pub  0.04
#
#
# -------Bathurst Manor, Wilson Heights, Downsview North-------
#          venue  freq
# 0  Pizza Place  0.07
# 1         Bank  0.07
# 2  Coffee Shop  0.07
# 3  Supermarket  0.03
# 4  Bridal Shop  0.03
#
#
# -------Bayview Village-------
#                  venue  freq
# 0                 Bank  0.12
# 1        Grocery Store  0.12
# 2  Japanese Restaurant  0.12
# 3          Gas Station  0.12
# 4                 Park  0.06
#
#
# -------Bedford Park, Lawrence Manor East-------
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.08
# 2                Bank  0.05
# 3                Park  0.05
# 4      Sandwich Place  0.05
#
#
# -------Berczy Park-------
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.07
# 2                Hotel  0.06
# 3  Japanese Restaurant  0.04
# 4           Restaurant  0.04
#
#
# -------Birch Cliff, Cliffside West-------
#                    venue  freq
# 0                   Park  0.21
# 1             Restaurant  0.07
# 2                   Café  0.07
# 3           Skating Rink  0.07
# 4  General Entertainment  0.07
#
#
# -------Brockton, Parkdale Village, Exhibition Place-------
#                     venue  freq
# 0                    Café  0.08
# 1             Coffee Shop  0.06
# 2              Restaurant  0.06
# 3                     Bar  0.05
# 4  Furniture / Home Store  0.04
#
#
# -------Business reply mail Processing Centre-------
#                 venue  freq
# 0                Park  0.10
# 1         Coffee Shop  0.08
# 2         Pizza Place  0.06
# 3             Brewery  0.06
# 4  Italian Restaurant  0.04
#
#
# -------CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport-------
#               venue  freq
# 0              Café  0.12
# 1   Harbor / Marina  0.12
# 2       Coffee Shop  0.12
# 3            Garden  0.06
# 4  Sculpture Garden  0.06
#
#
# -------Caledonia-Fairbanks-------
#                 venue  freq
# 0         Pizza Place  0.09
# 1                Park  0.09
# 2            Pharmacy  0.09
# 3                Bank  0.05
# 4  Falafel Restaurant  0.05
#
#
# -------Canada Post Gateway Processing Centre-------
#                        venue  freq
# 0                Coffee Shop  0.11
# 1                      Hotel  0.06
# 2  Middle Eastern Restaurant  0.06
# 3                        Gym  0.04
# 4           Asian Restaurant  0.04
#
#
# -------Cedarbrae-------
#                venue  freq
# 0             Bakery  0.10
# 1        Coffee Shop  0.10
# 2  Indian Restaurant  0.07
# 3               Bank  0.07
# 4        Gas Station  0.07
#
#
# -------Central Bay Street-------
#               venue  freq
# 0       Coffee Shop  0.10
# 1              Café  0.05
# 2  Sushi Restaurant  0.03
# 3              Park  0.03
# 4    Clothing Store  0.03
#
#
# -------Christie-------
#                venue  freq
# 0  Korean Restaurant  0.12
# 1               Café  0.07
# 2        Coffee Shop  0.06
# 3      Grocery Store  0.05
# 4       Cocktail Bar  0.03
#
#
# -------Church and Wellesley-------
#                  venue  freq
# 0          Coffee Shop  0.12
# 1     Sushi Restaurant  0.05
# 2                 Park  0.04
# 3  Japanese Restaurant  0.04
# 4                Diner  0.03
#
#
# -------Clarks Corners, Tam O'Shanter, Sullivan-------
#                   venue  freq
# 0           Coffee Shop  0.11
# 1        Sandwich Place  0.06
# 2           Pizza Place  0.06
# 3                  Bank  0.06
# 4  Fast Food Restaurant  0.06
#
#
# -------Cliffside, Cliffcrest, Scarborough Village West-------
#             venue  freq
# 0     Pizza Place  0.25
# 1  Ice Cream Shop  0.17
# 2           Beach  0.17
# 3      Sports Bar  0.08
# 4    Burger Joint  0.08
#
#
# -------Commerce Court, Victoria Hotel-------
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.07
# 2                Hotel  0.07
# 3  Japanese Restaurant  0.05
# 4   Seafood Restaurant  0.04
#
#
# -------Davisville-------
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.08
# 2    Sushi Restaurant  0.06
# 3         Pizza Place  0.04
# 4                Café  0.04
#
#
# -------Davisville North-------
#                 venue  freq
# 0         Coffee Shop  0.12
# 1  Italian Restaurant  0.06
# 2          Restaurant  0.04
# 3                Café  0.04
# 4            Pharmacy  0.03
#
#
# -------Del Ray, Mount Dennis, Keelsdale and Silverthorn-------
#                     venue  freq
# 0  Furniture / Home Store  0.19
# 1           Grocery Store  0.12
# 2              Restaurant  0.06
# 3             Video Store  0.06
# 4            Dessert Shop  0.06
#
#
# -------Don Mills-------
#                  venue  freq
# 0           Restaurant  0.08
# 1  Japanese Restaurant  0.07
# 2          Coffee Shop  0.07
# 3          Supermarket  0.04
# 4         Burger Joint  0.04
#
#
# -------Dorset Park, Wexford Heights, Scarborough Town Centre-------
#                   venue  freq
# 0           Coffee Shop  0.07
# 1            Restaurant  0.07
# 2     Electronics Store  0.07
# 3     Indian Restaurant  0.05
# 4  Fast Food Restaurant  0.05
#
#
# -------Downsview-------
#                    venue  freq
# 0            Coffee Shop  0.09
# 1  Vietnamese Restaurant  0.07
# 2            Pizza Place  0.06
# 3                  Hotel  0.06
# 4                   Park  0.04
#
#
# -------Dufferin, Dovercourt Village-------
#                 venue  freq
# 0                Café  0.10
# 1         Coffee Shop  0.09
# 2                Park  0.07
# 3              Bakery  0.04
# 4  Italian Restaurant  0.04
#
#
# -------East Toronto-------
#               venue  freq
# 0       Coffee Shop  0.08
# 1              Café  0.08
# 2  Greek Restaurant  0.07
# 3       Pizza Place  0.03
# 4          Beer Bar  0.03
#
#
# -------Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood-------
#                     venue  freq
# 0             Coffee Shop  0.12
# 1       Convenience Store  0.06
# 2  Transportation Service  0.06
# 3           Grocery Store  0.06
# 4            Liquor Store  0.06
#
#
# -------Fairview, Henry Farm, Oriole-------
#                  venue  freq
# 0       Clothing Store  0.14
# 1          Coffee Shop  0.11
# 2               Bakery  0.05
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.05
#
#
# -------First Canadian Place, Underground city-------
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                Hotel  0.07
# 2                 Café  0.07
# 3  Japanese Restaurant  0.04
# 4              Theater  0.03
#
#
# -------Forest Hill North & West-------
#               venue  freq
# 0              Park  0.08
# 1  Sushi Restaurant  0.08
# 2              Bank  0.06
# 3       Coffee Shop  0.06
# 4              Café  0.06
#
#
# -------Garden District, Ryerson-------
#                  venue  freq
# 0          Coffee Shop  0.10
# 1            Gastropub  0.06
# 2                 Café  0.04
# 3                Diner  0.04
# 4  Japanese Restaurant  0.04
#
#
# -------Glencairn-------
#                   venue  freq
# 0         Grocery Store  0.12
# 1  Fast Food Restaurant  0.09
# 2           Gas Station  0.06
# 3           Pizza Place  0.06
# 4                   Gym  0.06
#
#
# -------Golden Mile, Clairlea, Oakridge-------
#           venue  freq
# 0  Intersection  0.10
# 1         Diner  0.07
# 2      Bus Line  0.07
# 3   Coffee Shop  0.07
# 4        Bakery  0.07
#
#
# -------Guildwood, Morningside, West Hill-------
#                   venue  freq
# 0           Pizza Place  0.12
# 1                  Bank  0.08
# 2  Fast Food Restaurant  0.08
# 3           Coffee Shop  0.08
# 4              Pharmacy  0.04
#
#
# -------Harbourfront East, Union Station, Toronto Islands-------
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                 Café  0.07
# 2                Hotel  0.06
# 3  Japanese Restaurant  0.04
# 4                 Park  0.04
#
#
# -------High Park, The Junction South-------
#                 venue  freq
# 0                Café  0.08
# 1                 Bar  0.06
# 2         Coffee Shop  0.06
# 3  Italian Restaurant  0.04
# 4   Convenience Store  0.04
#
#
# -------Hillcrest Village-------
#                   venue  freq
# 0           Coffee Shop  0.10
# 1                  Park  0.10
# 2              Pharmacy  0.10
# 3        Ice Cream Shop  0.05
# 4  Fast Food Restaurant  0.05
#
#
# -------Humber Summit-------
#                  venue  freq
# 0    Electronics Store   0.2
# 1  Arts & Crafts Store   0.1
# 2          Pizza Place   0.1
# 3               Bakery   0.1
# 4        Shopping Mall   0.1
#
#
# -------Humberlea, Emery-------
#                venue  freq
# 0  Convenience Store  0.11
# 1       Intersection  0.11
# 2               Park  0.11
# 3     Discount Store  0.11
# 4        Gas Station  0.11
#
#
# -------Humewood-Cedarvale-------
#                venue  freq
# 0  Convenience Store  0.07
# 1      Grocery Store  0.07
# 2        Pizza Place  0.07
# 3        Coffee Shop  0.07
# 4  Food & Drink Shop  0.04
#
#
# -------India Bazaar, The Beaches West-------
#                   venue  freq
# 0     Indian Restaurant  0.08
# 1           Coffee Shop  0.06
# 2                  Park  0.05
# 3  Fast Food Restaurant  0.04
# 4                  Café  0.04
#
#
# -------Islington Avenue-------
#                venue  freq
# 0           Pharmacy  0.17
# 1  Convenience Store  0.08
# 2               Bank  0.08
# 3             Bakery  0.08
# 4      Shopping Mall  0.08
#
#
# -------Kennedy Park, Ionview, East Birchmount Park-------
#                   venue  freq
# 0    Chinese Restaurant  0.14
# 1           Coffee Shop  0.14
# 2        Discount Store  0.10
# 3  Fast Food Restaurant  0.07
# 4         Grocery Store  0.07
#
#
# -------Kensington Market, Chinatown, Grange Park-------
#                            venue  freq
# 0                           Café  0.10
# 1                            Bar  0.07
# 2                    Coffee Shop  0.04
# 3  Vegetarian / Vegan Restaurant  0.04
# 4                    Art Gallery  0.03
#
#
# -------Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens-------
#                venue  freq
# 0           Pharmacy  0.12
# 1               Bank  0.06
# 2   Business Service  0.06
# 3  Mobile Phone Shop  0.06
# 4        Supermarket  0.06
#
#
# -------Lawrence Manor, Lawrence Heights-------
#                     venue  freq
# 0  Furniture / Home Store  0.08
# 1             Coffee Shop  0.06
# 2              Restaurant  0.06
# 3           Women's Store  0.06
# 4          Clothing Store  0.06
#
#
# -------Lawrence Park-------
#                   venue  freq
# 0                  Café  0.22
# 1          College Quad  0.11
# 2             Bookstore  0.11
# 3  Gym / Fitness Center  0.11
# 4                 Trail  0.11
#
#
# -------Leaside-------
#                     venue  freq
# 0     Sporting Goods Shop  0.07
# 1             Coffee Shop  0.07
# 2           Grocery Store  0.05
# 3  Furniture / Home Store  0.05
# 4              Restaurant  0.03
#
#
# -------Little Portugal, Trinity-------
#                            venue  freq
# 0                           Café  0.09
# 1                            Bar  0.06
# 2                     Restaurant  0.06
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                         Bakery  0.04
#
#
# -------Malvern, Rouge-------
#                            venue  freq
# 0                          Trail  0.12
# 1           Fast Food Restaurant  0.12
# 2                           Bank  0.06
# 3            Arts & Crafts Store  0.06
# 4  Paper / Office Supplies Store  0.06
#
#
# -------Milliken, Agincourt North, Steeles East, L'Amoreaux East-------
#                   venue  freq
# 0    Chinese Restaurant  0.17
# 1  Fast Food Restaurant  0.07
# 2                  Park  0.07
# 3           Pizza Place  0.07
# 4          Noodle House  0.07
#
#
# -------Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West-------
#                   venue  freq
# 0            Restaurant  0.08
# 1         Burrito Place  0.05
# 2           Coffee Shop  0.05
# 3  Gym / Fitness Center  0.05
# 4                Bakery  0.03
#
#
# -------Moore Park, Summerhill East-------
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Italian Restaurant  0.07
# 2       Grocery Store  0.07
# 3                Park  0.05
# 4     Thai Restaurant  0.05
#
#
# -------New Toronto, Mimico South, Humber Bay Shores-------
#                 venue  freq
# 0                Park  0.11
# 1              Bakery  0.06
# 2         Pizza Place  0.06
# 3            Pharmacy  0.06
# 4  Mexican Restaurant  0.06
#
#
# -------North Park, Maple Leaf Park, Upwood Park-------
#                       venue  freq
# 0               Coffee Shop  0.18
# 1         Convenience Store  0.09
# 2               Pizza Place  0.09
# 3  Mediterranean Restaurant  0.09
# 4               Gas Station  0.09
#
#
# -------North Toronto West-------
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1         Coffee Shop  0.07
# 2                Park  0.04
# 3          Restaurant  0.04
# 4        Skating Rink  0.04
#
#
# -------Northwest-------
#          venue  freq
# 0        Hotel  0.25
# 1  Coffee Shop  0.25
# 2       Lounge  0.25
# 3      Dog Run  0.25
# 4    Pool Hall  0.00
#
#
# -------Northwood Park, York University-------
#                        venue  freq
# 0                Coffee Shop  0.14
# 1     Furniture / Home Store  0.09
# 2                Pizza Place  0.09
# 3                 Restaurant  0.09
# 4  Middle Eastern Restaurant  0.05
#
#
# -------Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East-------
#                          venue  freq
# 0           Italian Restaurant  0.25
# 1                         Park  0.25
# 2  Eastern European Restaurant  0.12
# 3               Ice Cream Shop  0.12
# 4                Shopping Mall  0.12
#
#
# -------Parkdale, Roncesvalles-------
#               venue  freq
# 0              Café  0.05
# 1  Sushi Restaurant  0.05
# 2               Bar  0.04
# 3       Coffee Shop  0.04
# 4       Pizza Place  0.04
#
#
# -------Parkview Hill, Woodbine Gardens-------
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1               Brewery  0.10
# 2           Pizza Place  0.10
# 3                  Bank  0.05
# 4    Rock Climbing Spot  0.05
#
#
# -------Parkwoods-------
#                venue  freq
# 0               Park  0.10
# 1  Convenience Store  0.07
# 2           Pharmacy  0.07
# 3      Shopping Mall  0.07
# 4           Bus Stop  0.07
#
#
# -------Queen's Park, Ontario Provincial Government-------
#               venue  freq
# 0       Coffee Shop  0.10
# 1  Sushi Restaurant  0.06
# 2              Park  0.04
# 3         Gastropub  0.03
# 4  Ramen Restaurant  0.03
#
#
# -------Regent Park, Harbourfront-------
#          venue  freq
# 0  Coffee Shop  0.16
# 1          Pub  0.04
# 2         Park  0.04
# 3      Theater  0.04
# 4        Diner  0.04
#
#
# -------Richmond, Adelaide, King-------
#          venue  freq
# 0  Coffee Shop  0.08
# 1         Café  0.08
# 2        Hotel  0.05
# 3     Tea Room  0.04
# 4      Theater  0.04
#
#
# -------Rosedale-------
#                 venue  freq
# 0                Park  0.14
# 1         Coffee Shop  0.14
# 2       Grocery Store  0.09
# 3   Convenience Store  0.05
# 4  Athletics & Sports  0.05
#
#
# -------Roselawn-------
#                 venue  freq
# 0            Pharmacy  0.09
# 1    Sushi Restaurant  0.09
# 2  Italian Restaurant  0.09
# 3                Café  0.09
# 4         Coffee Shop  0.09
#
#
# -------Rouge Hill, Port Union, Highland Creek-------
#                 venue  freq
# 0      Breakfast Spot   0.2
# 1        Burger Joint   0.2
# 2                Park   0.2
# 3          Playground   0.2
# 4  Italian Restaurant   0.2
#
#
# -------Runnymede, Swansea-------
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.09
# 2       Bakery  0.07
# 3  Pizza Place  0.07
# 4          Pub  0.04
#
#
# -------Runnymede, The Junction North-------
#             venue  freq
# 0     Pizza Place  0.11
# 1     Coffee Shop  0.11
# 2            Park  0.07
# 3         Brewery  0.07
# 4  Sandwich Place  0.04
#
#
# -------Scarborough Village-------
#                   venue  freq
# 0        Ice Cream Shop  0.14
# 1           Auto Garage  0.14
# 2  Fast Food Restaurant  0.07
# 3         Grocery Store  0.07
# 4         Bowling Alley  0.07
#
#
# -------South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens-------
#             venue  freq
# 0     Pizza Place  0.15
# 1   Grocery Store  0.15
# 2        Pharmacy  0.05
# 3        Gym Pool  0.05
# 4  Hardware Store  0.05
#
#
# -------St. James Town-------
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.08
# 2          Restaurant  0.06
# 3  Seafood Restaurant  0.04
# 4           Gastropub  0.04
#
#
# -------St. James Town, Cabbagetown-------
#                  venue  freq
# 0                 Park  0.09
# 1                 Café  0.06
# 2                Diner  0.06
# 3           Restaurant  0.06
# 4  Japanese Restaurant  0.06
#
#
# -------Steeles West, L'Amoreaux West-------
#                 venue  freq
# 0  Chinese Restaurant  0.14
# 1         Pizza Place  0.07
# 2         Coffee Shop  0.07
# 3              Bakery  0.07
# 4       Grocery Store  0.07
#
#
# -------Stn A PO Boxes-------
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.07
# 2                Hotel  0.05
# 3   Seafood Restaurant  0.04
# 4  Japanese Restaurant  0.04
#
#
# -------Studio District-------
#          venue  freq
# 0  Coffee Shop  0.07
# 1          Bar  0.06
# 2      Brewery  0.05
# 3         Café  0.05
# 4        Diner  0.04
#
#
# -------Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park-------
#                 venue  freq
# 0         Coffee Shop  0.09
# 1    Sushi Restaurant  0.06
# 2  Italian Restaurant  0.05
# 3     Thai Restaurant  0.05
# 4                Park  0.05
#
#
# -------The Annex, North Midtown, Yorkville-------
#                            venue  freq
# 0                           Café  0.06
# 1  Vegetarian / Vegan Restaurant  0.05
# 2             Italian Restaurant  0.04
# 3                    Coffee Shop  0.04
# 4                     Restaurant  0.03
#
#
# -------The Beaches-------
#                  venue  freq
# 0                  Pub  0.06
# 1          Coffee Shop  0.06
# 2          Pizza Place  0.05
# 3                Beach  0.05
# 4  Japanese Restaurant  0.04
#
#
# -------The Danforth West, Riverdale-------
#               venue  freq
# 0  Greek Restaurant  0.11
# 1       Coffee Shop  0.07
# 2              Café  0.06
# 3               Pub  0.05
# 4              Bank  0.03
#
#
# -------The Kingsway, Montgomery Road , Old Mill North-------
#           venue  freq
# 0   Coffee Shop  0.09
# 1          Park  0.06
# 2  Burger Joint  0.04
# 3  Dessert Shop  0.04
# 4          Bank  0.04
#
#
# -------Thorncliffe Park-------
#                 venue  freq
# 0         Coffee Shop  0.10
# 1   Indian Restaurant  0.06
# 2       Grocery Store  0.06
# 3                Bank  0.04
# 4  Turkish Restaurant  0.04
#
#
# -------Toronto Dominion Centre, Design Exchange-------
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                Hotel  0.07
# 2                 Café  0.07
# 3  Japanese Restaurant  0.05
# 4         Concert Hall  0.03
#
#
# -------University of Toronto, Harbord-------
#          venue  freq
# 0         Café  0.08
# 1       Bakery  0.06
# 2   Restaurant  0.05
# 3          Bar  0.05
# 4  Coffee Shop  0.04
#
#
# -------Victoria Village-------
#                    venue  freq
# 0            Coffee Shop  0.13
# 1  Portuguese Restaurant  0.07
# 2      French Restaurant  0.07
# 3            Golf Course  0.07
# 4                   Park  0.07
#
#
# -------West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale-------
#          venue  freq
# 0         Park  0.19
# 1  Pizza Place  0.12
# 2        Hotel  0.12
# 3   Restaurant  0.06
# 4         Café  0.06
#
#
# -------Westmount-------
#             venue  freq
# 0     Gas Station  0.12
# 1     Pizza Place  0.12
# 2  Ice Cream Shop  0.06
# 3  Discount Store  0.06
# 4     Flea Market  0.06
#
#
# -------Weston-------
#             venue  freq
# 0   Train Station  0.12
# 1     Coffee Shop  0.12
# 2            Café  0.06
# 3    Soccer Field  0.06
# 4  Sandwich Place  0.06
#
#
# -------Wexford, Maryvale-------
#                        venue  freq
# 0              Grocery Store  0.10
# 1  Middle Eastern Restaurant  0.10
# 2               Intersection  0.06
# 3               Burger Joint  0.06
# 4                Pizza Place  0.06
#
#
# -------Willowdale-------
#                venue  freq
# 0        Coffee Shop  0.06
# 1    Bubble Tea Shop  0.05
# 2        Pizza Place  0.05
# 3  Korean Restaurant  0.05
# 4   Ramen Restaurant  0.05
#
#
# -------Willowdale, Newtonbrook-------
#                        venue  freq
# 0          Korean Restaurant  0.13
# 1                       Café  0.10
# 2                      Diner  0.07
# 3                Coffee Shop  0.07
# 4  Middle Eastern Restaurant  0.07
#
#
# -------Woburn-------
#                   venue  freq
# 0                  Park   0.2
# 1           Coffee Shop   0.2
# 2     Indian Restaurant   0.1
# 3              Pharmacy   0.1
# 4  Fast Food Restaurant   0.1
#
#
# -------Woodbine Heights-------
#             venue  freq
# 0            Park  0.09
# 1     Coffee Shop  0.09
# 2    Skating Rink  0.06
# 3     Pizza Place  0.06
# 4  Sandwich Place  0.06
#
#
# -------York Mills West-------
#                venue  freq
# 0               Park  0.14
# 1         Restaurant  0.14
# 2        Coffee Shop  0.14
# 3  Convenience Store  0.05
# 4            Dog Run  0.05
#
#
# -------York Mills, Silver Hills-------
#                venue  freq
# 0               Park  0.75
# 1               Pool  0.25
# 2  Accessories Store  0.00
# 3        Music Venue  0.00
# 4       Optical Shop  0.00

# %% [markdown]
# ### Return TOP-10 categories for neighborhood

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# ### Group neighborhoods based on categories

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
# kmeans.labels_

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = pd.merge(left=neighborhoods_venues_sorted, right=df_2, left_on='Neighborhood', right_on='Neighborhood').drop(['PostalCode', 'Borough'], 1)
toronto_merged.set_index(['Neighborhood'], drop=True)
# Out:
#                                                  Cluster Labels  \
# Neighborhood
# Agincourt                                                     0
# Alderwood, Long Branch                                        0
# Bathurst Manor, Wilson Heights, Downsview North               0
# Bayview Village                                               2
# Bedford Park, Lawrence Manor East                             3
# ...                                                         ...
# Willowdale, Newtonbrook                                       3
# Woburn                                                        2
# Woodbine Heights                                              2
# York Mills West                                               2
# York Mills, Silver Hills                                      4
#
#                                                 1st Most Common Venue  \
# Neighborhood
# Agincourt                                          Chinese Restaurant
# Alderwood, Long Branch                                 Discount Store
# Bathurst Manor, Wilson Heights, Downsview North           Pizza Place
# Bayview Village                                                  Bank
# Bedford Park, Lawrence Manor East                  Italian Restaurant
# ...                                                               ...
# Willowdale, Newtonbrook                             Korean Restaurant
# Woburn                                                    Coffee Shop
# Woodbine Heights                                                 Park
# York Mills West                                                  Park
# York Mills, Silver Hills                                         Park
#
#                                                 2nd Most Common Venue  \
# Neighborhood
# Agincourt                                               Shopping Mall
# Alderwood, Long Branch                                       Pharmacy
# Bathurst Manor, Wilson Heights, Downsview North                  Bank
# Bayview Village                                   Japanese Restaurant
# Bedford Park, Lawrence Manor East                         Coffee Shop
# ...                                                               ...
# Willowdale, Newtonbrook                                          Café
# Woburn                                                           Park
# Woodbine Heights                                          Coffee Shop
# York Mills West                                            Restaurant
# York Mills, Silver Hills                                         Pool
#
#                                                 3rd Most Common Venue  \
# Neighborhood
# Agincourt                                                      Bakery
# Alderwood, Long Branch                                           Park
# Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# Bayview Village                                           Gas Station
# Bedford Park, Lawrence Manor East                                Park
# ...                                                               ...
# Willowdale, Newtonbrook                                   Pizza Place
# Woburn                                              Indian Restaurant
# Woodbine Heights                                          Pizza Place
# York Mills West                                           Coffee Shop
# York Mills, Silver Hills                                          Zoo
#
#                                                 4th Most Common Venue  \
# Neighborhood
# Agincourt                                        Caribbean Restaurant
# Alderwood, Long Branch                                    Pizza Place
# Bathurst Manor, Wilson Heights, Downsview North            Ski Chalet
# Bayview Village                                         Grocery Store
# Bedford Park, Lawrence Manor East                      Sandwich Place
# ...                                                               ...
# Willowdale, Newtonbrook                                         Diner
# Woburn                                             Chinese Restaurant
# Woodbine Heights                                         Skating Rink
# York Mills West                                     Convenience Store
# York Mills, Silver Hills                                  Event Space
#
#                                                      5th Most Common Venue  \
# Neighborhood
# Agincourt                                                     Skating Rink
# Alderwood, Long Branch                                         Coffee Shop
# Bathurst Manor, Wilson Heights, Downsview North             Ice Cream Shop
# Bayview Village                                              Shopping Mall
# Bedford Park, Lawrence Manor East                                     Bank
# ...                                                                    ...
# Willowdale, Newtonbrook                          Middle Eastern Restaurant
# Woburn                                                    Business Service
# Woodbine Heights                                            Sandwich Place
# York Mills West                                           Dentist's Office
# York Mills, Silver Hills                                  Doner Restaurant
#
#                                                 6th Most Common Venue  \
# Neighborhood
# Agincourt                                          Dim Sum Restaurant
# Alderwood, Long Branch                                  Garden Center
# Bathurst Manor, Wilson Heights, Downsview North           Supermarket
# Bayview Village                                    Chinese Restaurant
# Bedford Park, Lawrence Manor East                          Restaurant
# ...                                                               ...
# Willowdale, Newtonbrook                                   Coffee Shop
# Woburn                                                       Pharmacy
# Woodbine Heights                                      Thai Restaurant
# York Mills West                                           Gas Station
# York Mills, Silver Hills                                   Donut Shop
#
#                                                 7th Most Common Venue  \
# Neighborhood
# Agincourt                                              Discount Store
# Alderwood, Long Branch                                     Donut Shop
# Bathurst Manor, Wilson Heights, Downsview North   Fried Chicken Joint
# Bayview Village                                                  Café
# Bedford Park, Lawrence Manor East                    Sushi Restaurant
# ...                                                               ...
# Willowdale, Newtonbrook                             Indian Restaurant
# Woburn                                              Mobile Phone Shop
# Woodbine Heights                                                 Café
# York Mills West                                                  Bank
# York Mills, Silver Hills                          Dumpling Restaurant
#
#                                                        8th Most Common Venue  \
# Neighborhood
# Agincourt                                                               Bank
# Alderwood, Long Branch                                          Liquor Store
# Bathurst Manor, Wilson Heights, Downsview North               Sandwich Place
# Bayview Village                                                        Trail
# Bedford Park, Lawrence Manor East                                        Pub
# ...                                                                      ...
# Willowdale, Newtonbrook                                        Shopping Mall
# Woburn                                                  Fast Food Restaurant
# Woodbine Heights                                                    Pharmacy
# York Mills West                                                 Tennis Court
# York Mills, Silver Hills                         Eastern European Restaurant
#
#                                                 9th Most Common Venue  \
# Neighborhood
# Agincourt                                         Japanese Restaurant
# Alderwood, Long Branch                                  Shopping Mall
# Bathurst Manor, Wilson Heights, Downsview North                 Diner
# Bayview Village                                          Intersection
# Bedford Park, Lawrence Manor East                     Thai Restaurant
# ...                                                               ...
# Willowdale, Newtonbrook                                Sandwich Place
# Woburn                                                           Farm
# Woodbine Heights                                       Farmers Market
# York Mills West                                    Chinese Restaurant
# York Mills, Silver Hills                            Electronics Store
#
#                                                 10th Most Common Venue  \
# Neighborhood
# Agincourt                                                         Café
# Alderwood, Long Branch                                    Intersection
# Bathurst Manor, Wilson Heights, Downsview North             Restaurant
# Bayview Village                                             Restaurant
# Bedford Park, Lawrence Manor East                           Bagel Shop
# ...                                                                ...
# Willowdale, Newtonbrook                                    Supermarket
# Woburn                                               Elementary School
# Woodbine Heights                                              Bus Stop
# York Mills West                                      French Restaurant
# York Mills, Silver Hills                             Elementary School
#
#                                                   Latitude  Longitude
# Neighborhood
# Agincourt                                        43.794200 -79.262029
# Alderwood, Long Branch                           43.602414 -79.543484
# Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# Bayview Village                                  43.786947 -79.385975
# Bedford Park, Lawrence Manor East                43.733283 -79.419750
# ...                                                    ...        ...
# Willowdale, Newtonbrook                          43.789053 -79.408493
# Woburn                                           43.770992 -79.216917
# Woodbine Heights                                 43.695344 -79.318389
# York Mills West                                  43.752758 -79.400049
# York Mills, Silver Hills                         43.757490 -79.374714
#
# [102 rows x 13 columns]

# %%
map_clusters = folium.Map(location=[lat, long], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine clusters

# %% [markdown]
# #### Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[1:12]]
# Out:
#                                          Neighborhood  \
# 0                                           Agincourt
# 1                              Alderwood, Long Branch
# 2     Bathurst Manor, Wilson Heights, Downsview North
# 10                                Caledonia-Fairbanks
# 12                                          Cedarbrae
# 16            Clarks Corners, Tam O'Shanter, Sullivan
# 17    Cliffside, Cliffcrest, Scarborough Village West
# 21   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 24  Dorset Park, Wexford Heights, Scarborough Town...
# 25                                          Downsview
# 26                                          Downsview
# 27                                          Downsview
# 28                                          Downsview
# 36                                          Glencairn
# 37                    Golden Mile, Clairlea, Oakridge
# 38                  Guildwood, Morningside, West Hill
# 41                                  Hillcrest Village
# 42                                      Humber Summit
# 44                                 Humewood-Cedarvale
# 47        Kennedy Park, Ionview, East Birchmount Park
# 49  Kingsview Village, St. Phillips, Martin Grove ...
# 54                                     Malvern, Rouge
# 55  Milliken, Agincourt North, Steeles East, L'Amo...
# 59           North Park, Maple Leaf Park, Upwood Park
# 62                    Northwood Park, York University
# 65                    Parkview Hill, Woodbine Gardens
# 74                      Runnymede, The Junction North
# 75                                Scarborough Village
# 76  South Steeles, Silverstone, Humbergate, Jamest...
# 79                      Steeles West, L'Amoreaux West
# 87                                   Thorncliffe Park
# 92                                          Westmount
# 93                                             Weston
# 94                                  Wexford, Maryvale
# 95                                         Willowdale
# 96                                         Willowdale
#
#         1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0          Chinese Restaurant          Shopping Mall                Bakery
# 1              Discount Store               Pharmacy                  Park
# 2                 Pizza Place                   Bank           Coffee Shop
# 10                Pizza Place               Pharmacy                  Park
# 12                     Bakery            Coffee Shop     Indian Restaurant
# 16                Coffee Shop                   Bank           Pizza Place
# 17                Pizza Place         Ice Cream Shop                 Beach
# 21     Furniture / Home Store          Grocery Store            Restaurant
# 24          Electronics Store            Coffee Shop            Restaurant
# 25                Coffee Shop  Vietnamese Restaurant           Pizza Place
# 26                Coffee Shop  Vietnamese Restaurant           Pizza Place
# 27                Coffee Shop  Vietnamese Restaurant           Pizza Place
# 28                Coffee Shop  Vietnamese Restaurant           Pizza Place
# 36              Grocery Store   Fast Food Restaurant           Coffee Shop
# 37               Intersection            Coffee Shop              Bus Line
# 38                Pizza Place                   Bank  Fast Food Restaurant
# 41                       Park               Pharmacy           Coffee Shop
# 42          Electronics Store                 Bakery                  Park
# 44                Pizza Place      Convenience Store           Coffee Shop
# 47                Coffee Shop     Chinese Restaurant        Discount Store
# 49                   Pharmacy         Sandwich Place            Beer Store
# 54       Fast Food Restaurant                  Trail                   Gym
# 55         Chinese Restaurant            Pizza Place                  Park
# 59                Coffee Shop      Convenience Store           Gas Station
# 62                Coffee Shop             Restaurant           Pizza Place
# 65                    Brewery            Pizza Place  Fast Food Restaurant
# 74                Pizza Place            Coffee Shop               Brewery
# 75             Ice Cream Shop            Auto Garage         Grocery Store
# 76              Grocery Store            Pizza Place        Discount Store
# 79         Chinese Restaurant   Fast Food Restaurant           Pizza Place
# 87                Coffee Shop      Indian Restaurant         Grocery Store
# 92                Gas Station            Pizza Place        Discount Store
# 93                Coffee Shop          Train Station        Breakfast Spot
# 94  Middle Eastern Restaurant          Grocery Store          Intersection
# 95                Coffee Shop            Pizza Place       Bubble Tea Shop
# 96                Coffee Shop            Pizza Place       Bubble Tea Shop
#
#      4th Most Common Venue      5th Most Common Venue 6th Most Common Venue  \
# 0     Caribbean Restaurant               Skating Rink    Dim Sum Restaurant
# 1              Pizza Place                Coffee Shop         Garden Center
# 2               Ski Chalet             Ice Cream Shop           Supermarket
# 10                  Hostel        Japanese Restaurant           Coffee Shop
# 12             Gas Station                       Bank              Pharmacy
# 16          Sandwich Place       Fast Food Restaurant       Thai Restaurant
# 17              Sports Bar  Cajun / Creole Restaurant          Burger Joint
# 21             Video Store             Sandwich Place          Dessert Shop
# 24                Pharmacy         Chinese Restaurant     Indian Restaurant
# 25                   Hotel                       Park           Gas Station
# 26                   Hotel                       Park           Gas Station
# 27                   Hotel                       Park           Gas Station
# 28                   Hotel                       Park           Gas Station
# 36             Pizza Place                        Gym           Gas Station
# 37                   Diner                     Bakery           Pizza Place
# 38             Coffee Shop        Fried Chicken Joint         Grocery Store
# 41                  Bakery                Pizza Place         Shopping Mall
# 42             Pizza Place              Shopping Mall              Pharmacy
# 44           Grocery Store         Frozen Yogurt Shop          Optical Shop
# 47    Fast Food Restaurant              Grocery Store            Hobby Shop
# 49            Intersection                Supermarket    Chinese Restaurant
# 54     Arts & Crafts Store         Chinese Restaurant                  Bank
# 55            Noodle House       Fast Food Restaurant           Event Space
# 59      Chinese Restaurant         Dim Sum Restaurant                  Park
# 62  Furniture / Home Store       Caribbean Restaurant                   Bar
# 65      Athletics & Sports                   Pharmacy             Pet Store
# 74                    Park                 Beer Store           Gas Station
# 75     Japanese Restaurant              Train Station            Restaurant
# 76                Bus Line        Fried Chicken Joint            Beer Store
# 79                    Bank                     Bakery         Grocery Store
# 87                     Gym                       Bank           Supermarket
# 92             Coffee Shop             Sandwich Place    Chinese Restaurant
# 93          Sandwich Place     Furniture / Home Store        Discount Store
# 94            Burger Joint                Pizza Place     Korean Restaurant
# 95        Ramen Restaurant          Korean Restaurant   Japanese Restaurant
# 96        Ramen Restaurant          Korean Restaurant   Japanese Restaurant
#
#    7th Most Common Venue     8th Most Common Venue      9th Most Common Venue  \
# 0         Discount Store                      Bank        Japanese Restaurant
# 1             Donut Shop              Liquor Store              Shopping Mall
# 2    Fried Chicken Joint            Sandwich Place                      Diner
# 10        Discount Store                      Café                   Bus Stop
# 12  Fast Food Restaurant      Caribbean Restaurant               Burger Joint
# 16         Deli / Bodega        Seafood Restaurant               Intersection
# 17        Hardware Store                      Park                Event Space
# 21    Italian Restaurant                       Bar                Gas Station
# 24      Asian Restaurant                    Bakery       Fast Food Restaurant
# 25         Grocery Store        Turkish Restaurant             Discount Store
# 26         Grocery Store        Turkish Restaurant             Discount Store
# 27         Grocery Store        Turkish Restaurant             Discount Store
# 28         Grocery Store        Turkish Restaurant             Discount Store
# 36            Playground  Mediterranean Restaurant          Electronics Store
# 37  Fast Food Restaurant        Mexican Restaurant              Metro Station
# 38            Restaurant              Intersection         Chinese Restaurant
# 41     Korean Restaurant            Sandwich Place                       Bank
# 42    Italian Restaurant                      Bank        Arts & Crafts Store
# 44             Gastropub                Bagel Shop          Korean Restaurant
# 47                  Bank              Hockey Arena                   Pharmacy
# 49           Coffee Shop             Shopping Mall           Business Service
# 54                Bakery      Caribbean Restaurant                 Restaurant
# 55                Bakery         Korean Restaurant           Malay Restaurant
# 59    Athletics & Sports                    Bakery                Pizza Place
# 62    Chinese Restaurant          Sushi Restaurant  Middle Eastern Restaurant
# 65           Coffee Shop        Rock Climbing Spot                       Café
# 74              Bus Line        Athletics & Sports             Sandwich Place
# 75           Coffee Shop            Sandwich Place                Pizza Place
# 76          Liquor Store      Caribbean Restaurant             Sandwich Place
# 79           Coffee Shop            Breakfast Spot               Intersection
# 87    Turkish Restaurant                   Brewery               Burger Joint
# 92           Golf Course        Golf Driving Range               Intersection
# 93                 Diner                      Café        Fried Chicken Joint
# 94       Badminton Court       Rental Car Location                     Bakery
# 95              Pharmacy                      Bank       Fast Food Restaurant
# 96              Pharmacy                      Bank       Fast Food Restaurant
#
#        10th Most Common Venue
# 0                        Café
# 1                Intersection
# 2                  Restaurant
# 10         Falafel Restaurant
# 12            Thai Restaurant
# 16         Italian Restaurant
# 17        Dumpling Restaurant
# 21          Convenience Store
# 24             Sandwich Place
# 25       Fast Food Restaurant
# 26       Fast Food Restaurant
# 27       Fast Food Restaurant
# 28       Fast Food Restaurant
# 36  Latin American Restaurant
# 37                Bus Station
# 38                  Juice Bar
# 41         Chinese Restaurant
# 42                    Dog Run
# 44           Sushi Restaurant
# 47        Rental Car Location
# 49            Supplement Shop
# 54                Supermarket
# 55            Bubble Tea Shop
# 59   Mediterranean Restaurant
# 62                       Bank
# 65                Fabric Shop
# 74                        Bar
# 75          Convenience Store
# 76                       Park
# 79               Camera Store
# 87          Afghan Restaurant
# 92                Supermarket
# 93               Skating Rink
# 94                Gas Station
# 95             Sandwich Place
# 96             Sandwich Place

# %% [markdown]
# #### Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[1:12]]
# Out:
#                               Neighborhood 1st Most Common Venue  \
# 72  Rouge Hill, Port Union, Highland Creek        Breakfast Spot
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 72            Playground          Burger Joint                  Park
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 72    Italian Restaurant                   Zoo  Ethiopian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 72            Donut Shop   Dumpling Restaurant  Eastern European Restaurant

# %% [markdown]
# #### Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[1:12]]
# Out:
#                                           Neighborhood 1st Most Common Venue  \
# 3                                      Bayview Village                  Bank
# 6                          Birch Cliff, Cliffside West                  Park
# 34                            Forest Hill North & West                  Park
# 43                                    Humberlea, Emery      Business Service
# 46                                    Islington Avenue              Pharmacy
# 51                                       Lawrence Park                  Café
# 58        New Toronto, Mimico South, Humber Bay Shores                  Park
# 63   Old Mill South, King's Mill Park, Sunnylea, Hu...                  Park
# 66                                           Parkwoods                  Park
# 70                                            Rosedale                  Park
# 78                         St. James Town, Cabbagetown                  Park
# 91   West Deane Park, Princess Gardens, Martin Grov...                  Park
# 98                                              Woburn           Coffee Shop
# 99                                    Woodbine Heights                  Park
# 100                                    York Mills West                  Park
#
#      2nd Most Common Venue 3rd Most Common Venue        4th Most Common Venue  \
# 3      Japanese Restaurant           Gas Station                Grocery Store
# 6    General Entertainment              Gym Pool                        Diner
# 34        Sushi Restaurant           Coffee Shop                         Café
# 43        Storage Facility           Gas Station               Discount Store
# 46           Grocery Store                Bakery                         Café
# 51               Bookstore                  Park                 College Quad
# 58                  Bakery         Grocery Store           Mexican Restaurant
# 63      Italian Restaurant         Shopping Mall  Eastern European Restaurant
# 66                Bus Stop     Convenience Store                     Pharmacy
# 70             Coffee Shop         Grocery Store               Breakfast Spot
# 78                   Diner   Japanese Restaurant                   Restaurant
# 91             Pizza Place                 Hotel                      Theater
# 98                    Park     Indian Restaurant           Chinese Restaurant
# 99             Coffee Shop           Pizza Place                 Skating Rink
# 100             Restaurant           Coffee Shop            Convenience Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 3           Shopping Mall    Chinese Restaurant                  Café
# 6         Thai Restaurant          Dessert Shop                  Café
# 34                   Bank              Pharmacy                Bakery
# 43            Golf Course                  Park          Intersection
# 46          Shopping Mall           Golf Course          Skating Rink
# 51            College Gym           Coffee Shop                 Trail
# 58           Skating Rink                  Café          Liquor Store
# 63         Ice Cream Shop  Gym / Fitness Center                   Zoo
# 66          Shopping Mall                  Café        Discount Store
# 70                  Trail              Pie Shop        Sandwich Place
# 78              Gastropub                  Café  Caribbean Restaurant
# 91                    Gym    Mexican Restaurant                  Café
# 98       Business Service              Pharmacy     Mobile Phone Shop
# 99         Sandwich Place       Thai Restaurant                  Café
# 100      Dentist's Office           Gas Station                  Bank
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Trail          Intersection             Restaurant
# 6              Restaurant          Skating Rink                    Gym
# 34                  Trail    Italian Restaurant    Japanese Restaurant
# 43                 Bakery     Convenience Store                   Farm
# 46                   Park                  Bank      Convenience Store
# 51   Gym / Fitness Center                   Zoo   Ethiopian Restaurant
# 58    Fried Chicken Joint          Dessert Shop     Italian Restaurant
# 63      Elementary School      Doner Restaurant             Donut Shop
# 66   Caribbean Restaurant          Tennis Court            Supermarket
# 70            Candy Store   Filipino Restaurant          Metro Station
# 78             Steakhouse  Taiwanese Restaurant          Deli / Bodega
# 91                   Bank        Clothing Store             Restaurant
# 98   Fast Food Restaurant                  Farm      Elementary School
# 99               Pharmacy        Farmers Market               Bus Stop
# 100          Tennis Court    Chinese Restaurant      French Restaurant

# %% [markdown]
# #### Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[1:12]]
# Out:
#                                          Neighborhood   1st Most Common Venue  \
# 4                   Bedford Park, Lawrence Manor East      Italian Restaurant
# 5                                         Berczy Park             Coffee Shop
# 7        Brockton, Parkdale Village, Exhibition Place                    Café
# 8               Business reply mail Processing Centre                    Park
# 9   CN Tower, King and Spadina, Railway Lands, Har...         Harbor / Marina
# 11              Canada Post Gateway Processing Centre             Coffee Shop
# 13                                 Central Bay Street             Coffee Shop
# 14                                           Christie       Korean Restaurant
# 15                               Church and Wellesley             Coffee Shop
# 18                     Commerce Court, Victoria Hotel             Coffee Shop
# 19                                         Davisville      Italian Restaurant
# 20                                   Davisville North             Coffee Shop
# 22                                          Don Mills              Restaurant
# 23                                          Don Mills              Restaurant
# 29                       Dufferin, Dovercourt Village                    Café
# 30                                       East Toronto             Coffee Shop
# 31  Eringate, Bloordale Gardens, Old Burnhamthorpe...             Coffee Shop
# 32                       Fairview, Henry Farm, Oriole          Clothing Store
# 33             First Canadian Place, Underground city             Coffee Shop
# 35                           Garden District, Ryerson             Coffee Shop
# 39  Harbourfront East, Union Station, Toronto Islands             Coffee Shop
# 40                      High Park, The Junction South                    Café
# 45                     India Bazaar, The Beaches West       Indian Restaurant
# 48          Kensington Market, Chinatown, Grange Park                    Café
# 50                   Lawrence Manor, Lawrence Heights  Furniture / Home Store
# 52                                            Leaside             Coffee Shop
# 53                           Little Portugal, Trinity                    Café
# 56  Mimico NW, The Queensway West, South of Bloor,...              Restaurant
# 57                        Moore Park, Summerhill East             Coffee Shop
# 60                                 North Toronto West      Italian Restaurant
# 61                                          Northwest                  Lounge
# 64                             Parkdale, Roncesvalles                    Café
# 67        Queen's Park, Ontario Provincial Government             Coffee Shop
# 68                          Regent Park, Harbourfront             Coffee Shop
# 69                           Richmond, Adelaide, King                    Café
# 71                                           Roselawn             Coffee Shop
# 73                                 Runnymede, Swansea             Coffee Shop
# 77                                     St. James Town             Coffee Shop
# 80                                     Stn A PO Boxes             Coffee Shop
# 81                                    Studio District             Coffee Shop
# 82  Summerhill West, Rathnelly, South Hill, Forest...             Coffee Shop
# 83                The Annex, North Midtown, Yorkville                    Café
# 84                                        The Beaches                     Pub
# 85                       The Danforth West, Riverdale        Greek Restaurant
# 86     The Kingsway, Montgomery Road , Old Mill North             Coffee Shop
# 88           Toronto Dominion Centre, Design Exchange             Coffee Shop
# 89                     University of Toronto, Harbord                    Café
# 90                                   Victoria Village             Coffee Shop
# 97                            Willowdale, Newtonbrook       Korean Restaurant
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 4                     Coffee Shop                  Park
# 5                            Café                 Hotel
# 7                      Restaurant           Coffee Shop
# 8                     Coffee Shop               Brewery
# 9                            Café           Coffee Shop
# 11      Middle Eastern Restaurant                 Hotel
# 13                           Café             Gastropub
# 14                           Café           Coffee Shop
# 15               Sushi Restaurant                  Park
# 18                          Hotel                  Café
# 19                    Coffee Shop      Sushi Restaurant
# 20             Italian Restaurant            Restaurant
# 22            Japanese Restaurant           Coffee Shop
# 23            Japanese Restaurant           Coffee Shop
# 29                    Coffee Shop                  Park
# 30                           Café      Greek Restaurant
# 31              Convenience Store        Farmers Market
# 32                    Coffee Shop                  Bank
# 33                           Café                 Hotel
# 35                      Gastropub                  Café
# 39                           Café                 Hotel
# 40                    Coffee Shop                   Bar
# 45                    Coffee Shop                  Park
# 48                            Bar           Coffee Shop
# 50                 Clothing Store         Women's Store
# 52            Sporting Goods Shop         Grocery Store
# 53                            Bar            Restaurant
# 56                    Coffee Shop  Gym / Fitness Center
# 57             Italian Restaurant         Grocery Store
# 60                    Coffee Shop          Skating Rink
# 61                          Hotel           Coffee Shop
# 64               Sushi Restaurant           Pizza Place
# 67               Sushi Restaurant                  Park
# 68                           Park                  Café
# 69                    Coffee Shop                 Hotel
# 71                           Bank      Sushi Restaurant
# 73                           Café           Pizza Place
# 77                           Café            Restaurant
# 80                           Café                 Hotel
# 81                            Bar               Brewery
# 82               Sushi Restaurant    Italian Restaurant
# 83  Vegetarian / Vegan Restaurant    Italian Restaurant
# 84                    Coffee Shop           Pizza Place
# 85                    Coffee Shop                  Café
# 86                           Park                   Pub
# 88                          Hotel                  Café
# 89                         Bakery            Restaurant
# 90          Portuguese Restaurant  Gym / Fitness Center
# 97                           Café           Pizza Place
#
#             4th Most Common Venue      5th Most Common Venue  \
# 4                  Sandwich Place                       Bank
# 5                      Restaurant        Japanese Restaurant
# 7                             Bar                     Bakery
# 8                     Pizza Place           Sushi Restaurant
# 9                    Dance Studio                     Garden
# 11                         Bakery         Mexican Restaurant
# 13               Sushi Restaurant                       Park
# 14                  Grocery Store             Ice Cream Shop
# 15            Japanese Restaurant                      Diner
# 18            Japanese Restaurant                 Restaurant
# 19                    Pizza Place                       Café
# 20                           Café                        Gym
# 22                    Supermarket                       Bank
# 23                    Supermarket                       Bank
# 29             Italian Restaurant                     Bakery
# 30           Ethiopian Restaurant                Pizza Place
# 31                     Beer Store              Shopping Mall
# 32                 Sandwich Place                     Bakery
# 33            Japanese Restaurant                 Restaurant
# 35            Japanese Restaurant                      Diner
# 39            Japanese Restaurant                       Park
# 40             Italian Restaurant          Convenience Store
# 45                     Restaurant                      Beach
# 48  Vegetarian / Vegan Restaurant                Yoga Studio
# 50           Fast Food Restaurant                Coffee Shop
# 52         Furniture / Home Store           Department Store
# 53  Vegetarian / Vegan Restaurant                     Bakery
# 56                  Burrito Place               Burger Joint
# 57                Thai Restaurant                        Gym
# 60            Sporting Goods Shop             Clothing Store
# 61                        Dog Run                        Zoo
# 64                  Grocery Store                        Bar
# 67                           Café           Ramen Restaurant
# 68                        Theater                        Pub
# 69                       Tea Room                    Theater
# 71                       Pharmacy         Italian Restaurant
# 73                         Bakery         Italian Restaurant
# 77             Seafood Restaurant                  Gastropub
# 80             Seafood Restaurant                 Restaurant
# 81                           Café        American Restaurant
# 82                           Park            Thai Restaurant
# 83                    Coffee Shop                Pizza Place
# 84                          Beach        Japanese Restaurant
# 85                            Pub                       Bank
# 86              French Restaurant                Pizza Place
# 88            Japanese Restaurant         Seafood Restaurant
# 89                            Bar                Coffee Shop
# 90                           Café                     Lounge
# 97                          Diner  Middle Eastern Restaurant
#
#      6th Most Common Venue          7th Most Common Venue  \
# 4               Restaurant               Sushi Restaurant
# 5                     Park                            Gym
# 7   Furniture / Home Store                      Gift Shop
# 8                   Bakery             Italian Restaurant
# 9         Sculpture Garden               Sushi Restaurant
# 11                     Gym                  Burrito Place
# 13          Clothing Store               Ramen Restaurant
# 14      Mexican Restaurant                   Cocktail Bar
# 15                    Café                Thai Restaurant
# 18      Seafood Restaurant                   Concert Hall
# 19       Indian Restaurant                   Dessert Shop
# 20    Fast Food Restaurant                    Pizza Place
# 22                     Gym               Asian Restaurant
# 23                     Gym               Asian Restaurant
# 29        Sushi Restaurant                            Bar
# 30                Beer Bar           Fast Food Restaurant
# 31            Liquor Store                           Café
# 32              Restaurant            Japanese Restaurant
# 33                 Theater                   Concert Hall
# 35                 Theater                     Restaurant
# 39                     Gym                        Theater
# 40         Thai Restaurant               Sushi Restaurant
# 45                    Café           Fast Food Restaurant
# 48             Art Gallery                         Bakery
# 50              Restaurant            Fried Chicken Joint
# 52       Electronics Store                   Burger Joint
# 53        Asian Restaurant         Furniture / Home Store
# 56      Italian Restaurant              Convenience Store
# 57                    Park                           Bank
# 60      Mexican Restaurant                     Restaurant
# 61              Donut Shop            Dumpling Restaurant
# 64             Coffee Shop                Thai Restaurant
# 67               Gastropub             Italian Restaurant
# 68                   Diner             Italian Restaurant
# 69              Restaurant            Japanese Restaurant
# 71                    Café                            Gym
# 73                     Pub               Sushi Restaurant
# 77      Italian Restaurant                        Theater
# 80     Japanese Restaurant                      Gastropub
# 81   Vietnamese Restaurant                         Bakery
# 82           Grocery Store                           Café
# 83           Grocery Store                            Gym
# 84                  Bakery                 Breakfast Spot
# 85    Fast Food Restaurant             Italian Restaurant
# 86            Burger Joint                 Breakfast Spot
# 88                 Theater                     Restaurant
# 89               Bookstore  Vegetarian / Vegan Restaurant
# 90       French Restaurant                           Park
# 97             Coffee Shop              Indian Restaurant
#
#           8th Most Common Venue      9th Most Common Venue  \
# 4                           Pub            Thai Restaurant
# 5                        Bakery              Grocery Store
# 7            Tibetan Restaurant      Performing Arts Venue
# 8          Fast Food Restaurant       Gym / Fitness Center
# 9                         Track                       Park
# 11             Sushi Restaurant          Indian Restaurant
# 13          Japanese Restaurant                    Theater
# 14          Japanese Restaurant                       Park
# 15                  Pizza Place                Men's Store
# 18                        Plaza              Deli / Bodega
# 19                   Restaurant                        Gym
# 20             Sushi Restaurant               Dessert Shop
# 22                 Burger Joint         Salon / Barbershop
# 23                 Burger Joint         Salon / Barbershop
# 29                      Brewery      Portuguese Restaurant
# 30               Breakfast Spot                     Bakery
# 31                  Gas Station     Transportation Service
# 32          Sporting Goods Shop               Liquor Store
# 33           Seafood Restaurant                       Park
# 35                        Hotel         Italian Restaurant
# 39                      Brewery             Scenic Lookout
# 40                          Gym              Deli / Bodega
# 45                      Brewery            Harbor / Marina
# 48           Mexican Restaurant       Caribbean Restaurant
# 50             Sushi Restaurant         Seafood Restaurant
# 52                      Brewery                 Restaurant
# 53                  Pizza Place               Cocktail Bar
# 56               Sandwich Place              Grocery Store
# 57                  Pizza Place           Sushi Restaurant
# 60                        Diner                       Park
# 61  Eastern European Restaurant          Electronics Store
# 64               Breakfast Spot                        Pub
# 67                   Restaurant  Middle Eastern Restaurant
# 68               Breakfast Spot                     Bakery
# 69       Furniture / Home Store         Seafood Restaurant
# 71           Chinese Restaurant                 Bagel Shop
# 73                         Bank                  Gastropub
# 77                        Hotel                   Creperie
# 80                         Park              Deli / Bodega
# 81                        Diner          French Restaurant
# 82                          Spa                        Pub
# 83                   Restaurant                     Bakery
# 84                          Bar             Sandwich Place
# 85               Discount Store                     Bakery
# 86                         Bank         Italian Restaurant
# 88                 Concert Hall                      Plaza
# 89           Mexican Restaurant        Arts & Crafts Store
# 90                  Golf Course               Intersection
# 97                Shopping Mall             Sandwich Place
#
#        10th Most Common Venue
# 4                  Bagel Shop
# 5                Liquor Store
# 7                        Park
# 8             Thai Restaurant
# 9              Scenic Lookout
# 11        Fried Chicken Joint
# 13                Yoga Studio
# 14                        Bar
# 15           Ramen Restaurant
# 18            Thai Restaurant
# 19             Sandwich Place
# 20                   Pharmacy
# 22        Sporting Goods Shop
# 23        Sporting Goods Shop
# 29                 Restaurant
# 30                       Bank
# 31              Grocery Store
# 32         Salon / Barbershop
# 33                      Plaza
# 35  Middle Eastern Restaurant
# 39           Baseball Stadium
# 40                 Nail Salon
# 45                        Gym
# 48                Pizza Place
# 50               Dessert Shop
# 52                 Sports Bar
# 53         Italian Restaurant
# 56           Sushi Restaurant
# 57                        Pub
# 60                       Café
# 61          Elementary School
# 64             Sandwich Place
# 67        Japanese Restaurant
# 68                 Restaurant
# 69                      Plaza
# 71    Fruit & Vegetable Store
# 73         Falafel Restaurant
# 77                      Plaza
# 80                   Creperie
# 81         Italian Restaurant
# 82                       Bank
# 83                     Museum
# 84              Grocery Store
# 85     Furniture / Home Store
# 86               Dessert Shop
# 88            Thai Restaurant
# 89                Pizza Place
# 90              Grocery Store
# 97                Supermarket

# %% [markdown]
# #### Cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[1:12]]
# Out:
#                  Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 101  York Mills, Silver Hills                  Park                  Pool
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 101                   Zoo           Event Space      Doner Restaurant
#
#     6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 101            Donut Shop   Dumpling Restaurant  Eastern European Restaurant
#
#     9th Most Common Venue 10th Most Common Venue
# 101     Electronics Store      Elementary School
